# %%
import pandas as pd

# %%
df = pd.read_csv("gplay.csv")
df
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10836       10836                                   Sya9a Maroc - FR
# 10837       10837                   Fr. Mike Schmitz Audio Teachings
# 10838       10838                             Parkinson Exercices FR
# 10839       10839                      The SCP Foundation DB fr nn5n
# 10840       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10841 non-null  int64
#  1   App             10841 non-null  object
#  2   Category        10841 non-null  object
#  3   Rating          9367 non-null   float64
#  4   Reviews         10841 non-null  object
#  5   Size            10841 non-null  object
#  6   Installs        10841 non-null  object
#  7   Type            10840 non-null  object
#  8   Price           10841 non-null  object
#  9   Content Rating  10840 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 847.1+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating'],
#       dtype='object')

# %%
#Drop Unwanted Cols

df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# dtype: int64

# %%
1474/10841
# Out:
# 0.13596531685268887

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 762.4+ KB

# %%
rm = df["Rating"].mean()

# %%
df["Rating"].fillna(rm,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 762.4+ KB

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  object
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 846.8+ KB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone

# %%
df["Reviews"]=df["Reviews"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 846.8+ KB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone

# %%
df["Size"].value_counts()
# Out:
# Varies with device    1694
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: Size, Length: 461, dtype: int64

# %%
import numpy as np

# %%
def clean_size(x):
    if "k" in x:
        x=x.replace("k","")
        return float(x)/1024
    
    elif "M" in x:
        x=x.replace("M","")
        return float(x)
    
    elif "Varies with device" in x:
        return np.nan
    
    else:
        return float(x)

# %%
df["Size"]=df["Size"].map(clean_size)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            9145 non-null   float64
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 846.8+ KB

# %%
sm = df["Size"].mean()
sm
# Out:
# 21.516165435774777

# %%
df["Size"].fillna(sm,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  float64
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 846.8+ KB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating
# 0     159.0  19.0      10,000+  Free     0       Everyone
# 1     967.0  14.0     500,000+  Free     0       Everyone
# 2   87510.0   8.7   5,000,000+  Free     0       Everyone
# 3  215644.0  25.0  50,000,000+  Free     0           Teen
# 4     967.0   2.8     100,000+  Free     0       Everyone

# %%
df["Installs"]=df["Installs"].str.replace(",","")

df["Installs"]=df["Installs"].str.replace("+","")
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_11556\4178109572.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Installs"]=df["Installs"].str.replace("+","")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type Price Content Rating
# 0     159.0  19.0     10000  Free     0       Everyone
# 1     967.0  14.0    500000  Free     0       Everyone
# 2   87510.0   8.7   5000000  Free     0       Everyone
# 3  215644.0  25.0  50000000  Free     0           Teen
# 4     967.0   2.8    100000  Free     0       Everyone

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  float64
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 846.8+ KB

# %%
df["Installs"]=df["Installs"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  float64
#  5   Installs        10839 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
# dtypes: float64(3), int32(1), object(5)
# memory usage: 804.5+ KB

# %%
df["Type"].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
df["Price"].value_counts()
# Out:
# 0         10039
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: Price, Length: 92, dtype: int64

# %%
df["Price"]=df["Price"].str.replace("$","")
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_11556\1749981031.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Price"]=df["Price"].str.replace("$","")

# %%
df["Price"].value_counts()
# Out:
# 0        10039
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 19.90        1
# 1.75         1
# 14.00        1
# 4.85         1
# 1.04         1
# Name: Price, Length: 92, dtype: int64

# %%
df["Price"]=df["Price"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          10839 non-null  float64
#  3   Reviews         10839 non-null  float64
#  4   Size            10839 non-null  float64
#  5   Installs        10839 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  float64
#  8   Content Rating  10839 non-null  object
# dtypes: float64(4), int32(1), object(4)
# memory usage: 804.5+ KB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type  Price Content Rating
# 0     159.0  19.0     10000  Free    0.0       Everyone
# 1     967.0  14.0    500000  Free    0.0       Everyone
# 2   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25.0  50000000  Free    0.0           Teen
# 4     967.0   2.8    100000  Free    0.0       Everyone

# %%
#Highest Rating

df["Rating"].max()
# Out:
# 5.0

# %%
#Display all the records having rating 4.0

df[df["Rating"]==4.0]
# Out:
#                                                  App           Category  \
# 20                       Logo Maker - Small Business     ART_AND_DESIGN
# 39     How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 50                              Real Tractor Farming  AUTO_AND_VEHICLES
# 58                                 Restart Navigator  AUTO_AND_VEHICLES
# 66                                  Used Cars Mexico  AUTO_AND_VEHICLES
# ...                                              ...                ...
# 10802                            FR: My Famous Lover             FAMILY
# 10814                           FR: My Secret Pets!              FAMILY
# 10817                           HTC Sense Input - FR              TOOLS
# 10826      Frim: get new friends on local chat rooms             SOCIAL
# 10834                                  FR Calculator             FAMILY
#
#        Rating  Reviews       Size  Installs  Type  Price Content Rating
# ...

# %%
df.loc[df["Rating"]==4.0]
# Out:
#                                                  App           Category  \
# 20                       Logo Maker - Small Business     ART_AND_DESIGN
# 39     How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 50                              Real Tractor Farming  AUTO_AND_VEHICLES
# 58                                 Restart Navigator  AUTO_AND_VEHICLES
# 66                                  Used Cars Mexico  AUTO_AND_VEHICLES
# ...                                              ...                ...
# 10802                            FR: My Famous Lover             FAMILY
# 10814                           FR: My Secret Pets!              FAMILY
# 10817                           HTC Sense Input - FR              TOOLS
# 10826      Frim: get new friends on local chat rooms             SOCIAL
# 10834                                  FR Calculator             FAMILY
#
#        Rating  Reviews       Size  Installs  Type  Price Content Rating
# ...

# %%
#Display all records having Max Rating

rmax=df["Rating"].max()

df.loc[df["Rating"]==rmax]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0     15.0
# 612                 American Girls Mobile Numbers     DATING     5.0      5.0
# 615                                  Awake Dating     DATING     5.0      2.0
# 633                         Spine- The dating app     DATING     5.0      5.0
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0      6.0
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0     14.0
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0     32.0
# 10776                            Monster Ride Pro       GAME     5.0      1.0
# 10820                             Fr. Daoud Lamei     FAMILY     5.0     22.0
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0      4.0
#
# ...

# %%
rmax=df["Rating"].max()

df[df["Rating"]==rmax]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0     15.0
# 612                 American Girls Mobile Numbers     DATING     5.0      5.0
# 615                                  Awake Dating     DATING     5.0      2.0
# 633                         Spine- The dating app     DATING     5.0      5.0
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0      6.0
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0     14.0
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0     32.0
# 10776                            Monster Ride Pro       GAME     5.0      1.0
# 10820                             Fr. Daoud Lamei     FAMILY     5.0     22.0
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0      4.0
#
# ...

# %%
#Display only Apps name, Category and Rating whose rating values is 3.0

df[["App","Category","Rating"]].loc[df["Rating"]==3.0]
# Out:
#                                                     App       Category  Rating
# 514                                  FarmersOnly Dating         DATING     3.0
# 546                                          The League         DATING     3.0
# 619                      Random Chat App with Strangers         DATING     3.0
# 645                             UK Girls Mobile Numbers         DATING     3.0
# 915    Acorn TV: World-class TV from Britain and Beyond  ENTERTAINMENT     3.0
# ...                                                 ...            ...     ...
# 10151                                           EZ View       BUSINESS     3.0
# 10325                                         FE Mobile       BUSINESS     3.0
# 10341                                            FE CPS        FINANCE     3.0
# 10476                             Lennox iComfort Wi-Fi      LIFESTYLE     3.0
# 10715                                FarmersOnly Dating         DATING     3.0
#
# [83 rows x 3 columns]

# %%
#Display all records of Free Apps

df[df["Type"]=="Free"]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df["Type"]=="Paid"]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#          Rating  Reviews       Size  Installs  Type  Price Content Rating
# ...

# %%
# Display Expensive Apps

pmax=df["Price"].max()

df[df["Price"]==pmax]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7.3     10000
#
#       Type  Price Content Rating
# 4367  Paid  400.0       Everyone

# %%
#Display Records whose Rating between 4 to 5

df[(df["Rating"]>=4.0) & (df["Rating"]<=5.0)]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[(df["Rating"]>=4.0) | (df["Rating"]<=5.0)]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Display All Free Records Having Rating Is 5.0

df[(df['Type']=="Free") & (df["Rating"]==5.0)]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0     15.0
# 612                 American Girls Mobile Numbers     DATING     5.0      5.0
# 615                                  Awake Dating     DATING     5.0      2.0
# 633                         Spine- The dating app     DATING     5.0      5.0
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0      6.0
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0     14.0
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0     32.0
# 10776                            Monster Ride Pro       GAME     5.0      1.0
# 10820                             Fr. Daoud Lamei     FAMILY     5.0     22.0
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0      4.0
#
# ...

# %%
df[(df['Type']=="Paid") & (df["Rating"]==5.0)]
# Out:
#                                                      App             Category  \
# 2262            Super Hearing Secret Voices Recorder PRO              MEDICAL
# 2271                                      FHR 5-Tier 2.0              MEDICAL
# 3957                                        ADS-B Driver                TOOLS
# 4452                                     P-Home for KLWP      PERSONALIZATION
# 4477                           Android P Style Icon Pack      PERSONALIZATION
# 4988                                Easy Hotspot Ad Free                TOOLS
# 5237                              Hey AJ! It's Saturday!  BOOKS_AND_REFERENCE
# 5246                               Hey AJ! It's Bedtime!               FAMILY
# 5260                              AJ Gray Dark Icon Pack      PERSONALIZATION
# 5263                                   AJ Blue Icon Pack      PERSONALIZATION
# 5482                          meStudying: AP English Lit               FAMILY
# ...

# %%
rmin = df["Rating"].min()

# %%
# Display Records of low rated app of paid category

df[(df["Type"]=="Paid") & (df["Rating"]==rmin)]
# Out:
#                                 App Category  Rating  Reviews  Size  Installs  \
# 4127              Speech Therapy: F   FAMILY     1.0      1.0  16.0        10
# 5978  Truck Driving Test Class 3 BC   FAMILY     1.0      1.0   2.0        50
#
#       Type  Price Content Rating
# 4127  Paid   2.99       Everyone
# 5978  Paid   1.49       Everyone

# %%
df[(df["Type"]=="Paid") | (df.min("Rating"))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'Rating'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [66], line 1
# ----> 1 df[(df["Type"]=="Paid") | (df.min("Rating"))]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11244, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11224 @doc(  # type: ignore[misc]
#   11225     _num_doc,
#   11226     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11242     **kwargs,
#   11243 ):
# ...
