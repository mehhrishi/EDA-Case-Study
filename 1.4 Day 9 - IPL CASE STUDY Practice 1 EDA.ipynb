# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Match.csv")
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.batsman

# %%
df.shape
# Out:
# (69761, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69761 entries, 0 to 69760
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          69761 non-null  int64
#  1   inning            69761 non-null  int64
#  2   batting_team      69761 non-null  object
#  3   bowling_team      69761 non-null  object
#  4   over              69761 non-null  int64
#  5   ball              69761 non-null  int64
#  6   batsman           69761 non-null  object
#  7   non_striker       69761 non-null  object
#  8   bowler            69761 non-null  object
#  9   is_super_over     69761 non-null  int64
#  10  wide_runs         69761 non-null  int64
#  11  bye_runs          69761 non-null  int64
#  12  legbye_runs       69761 non-null  int64
#  13  noball_runs       69761 non-null  int64
#  14  penalty_runs      69761 non-null  int64
#  15  batsman_runs      69761 non-null  int64
# ...

# %%
df[["player_dismissed"]].value_counts()
# Out:
# player_dismissed
# RG Sharma           59
# SK Raina            59
# AC Gilchrist        57
# G Gambhir           56
# Yuvraj Singh        55
#                     ..
# A Choudhary          1
# BAW Mendis           1
# H Das                1
# GR Napier            1
# Jaskaran Singh       1
# Length: 354, dtype: int64

# %%
df[["fielder"]].value_counts()
# Out:
# fielder
# RV Uthappa         61
# KD Karthik         57
# MS Dhoni           55
# AC Gilchrist       54
# KC Sangakkara      46
#                    ..
# RA Jadeja (sub)     1
# Misbah-ul-Haq       1
# AD Mascarenhas      1
# M Kaif (sub)        1
# KS Williamson       1
# Length: 352, dtype: int64

# %%
df[["dismissal_kind"]].value_counts()
# Out:
# dismissal_kind
# caught               2029
# bowled                650
# run out               379
# lbw                   223
# stumped               121
# caught and bowled     106
# hit wicket              4
# retired hurt            4
# dtype: int64

# %%
#Find Team wise runs scored.
df.groupby('batting_team')[['total_runs']].sum()
# Out:
#                              total_runs
# batting_team
# Chennai Super Kings                9253
# Deccan Chargers                    8931
# Delhi Daredevils                  10654
# Gujarat Lions                      2412
# Kings XI Punjab                   10763
# Kochi Tuskers Kerala               1760
# Kolkata Knight Riders              9924
# Mumbai Indians                    11202
# Pune Warriors                      1657
# Rajasthan Royals                   8039
# Rising Pune Supergiant             2470
# Royal Challengers Bangalore       10221
# Sunrisers Hyderabad                2349

# %%
df.groupby('batting_team')['total_runs'].sum()
# Out:
# batting_team
# Chennai Super Kings             9253
# Deccan Chargers                 8931
# Delhi Daredevils               10654
# Gujarat Lions                   2412
# Kings XI Punjab                10763
# Kochi Tuskers Kerala            1760
# Kolkata Knight Riders           9924
# Mumbai Indians                 11202
# Pune Warriors                   1657
# Rajasthan Royals                8039
# Rising Pune Supergiant          2470
# Royal Challengers Bangalore    10221
# Sunrisers Hyderabad             2349
# Name: total_runs, dtype: int64

# %%
df[['batting_team','total_runs']][['batting_team','total_runs']].sum()
# Out:
# batting_team    Sunrisers HyderabadSunrisers HyderabadSunriser...
# total_runs                                                  89635
# dtype: object

# %%
df.groupby('batting_team').loc[:,['total_runs']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 df.groupby('batting_team').loc[:,['total_runs']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
df.loc[:,['batting_team','total_runs']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df.loc[:,['batting_team','total_runs']].unique()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
# Find Total Runs of Virat Kohli.
df[(df['batsman']=='V Kohli')][['total_runs']].sum()

# df[(df.batsman=='V Kohli')][['batsman','total_runs']].sum()

# %%
df.groupby('batsman').get_group('V Kohli')['total_runs'].sum()
# Out:
# 1499

# %%
df.groupby('batsman').get_group('V Kohli')[['total_runs']].sum()
# Out:
# total_runs    1499
# dtype: int64

# %%
df.groupby('batsman').get_group('V Kohli').loc[:,['total_runs']].sum()
# Out:
# total_runs    1499
# dtype: int64

# %%
df.groupby('batsman').get_group('V Kohli').iloc[:,[-4]].sum()
# Out:
# total_runs    1499
# dtype: int64

# %%
df.groupby('batsman').loc[:,['total_runs']].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 df.groupby('batsman').loc[:,['total_runs']].sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
df.groupby('batsman').iloc[:,[-4]].sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69761 entries, 0 to 69760
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          69761 non-null  int64
#  1   inning            69761 non-null  int64
#  2   batting_team      69761 non-null  object
#  3   bowling_team      69761 non-null  object
#  4   over              69761 non-null  int64
#  5   ball              69761 non-null  int64
#  6   batsman           69761 non-null  object
#  7   non_striker       69761 non-null  object
#  8   bowler            69761 non-null  object
#  9   is_super_over     69761 non-null  int64
#  10  wide_runs         69761 non-null  int64
#  11  bye_runs          69761 non-null  int64
#  12  legbye_runs       69761 non-null  int64
#  13  noball_runs       69761 non-null  int64
#  14  penalty_runs      69761 non-null  int64
#  15  batsman_runs      69761 non-null  int64
# ...

# %%
df[['batsman']]
# Out:
#             batsman
# 0         DA Warner
# 1         DA Warner
# 2         DA Warner
# 3         DA Warner
# 4         DA Warner
# ...             ...
# 69756     JP Duminy
# 69757     JP Duminy
# 69758     JP Duminy
# 69759     JP Duminy
# 69760  DT Christian
#
# [69761 rows x 1 columns]

# %%
df[['batsman']].value_counts()
# Out:
# batsman
# SK Raina          1576
# G Gambhir         1573
# RG Sharma         1418
# JH Kallis         1390
# SR Tendulkar      1388
#                   ...
# P Parameswaran       1
# AD Nath              1
# C Nanda              1
# U Kaul               1
# A Mukund             1
# Length: 383, dtype: int64

# %%
df.loc[:,['batsman']].values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df.loc[:,['batsman']].values_counts()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'values_counts'

# %%
df.groupby('batsman')[['batsman']].unique()

# %%
# Find Total Runs of Your Fav Player.

df.groupby('batsman').get_group("SR Tendulkar")[['total_runs']].sum()
# Out:
# total_runs    1730
# dtype: int64

# %%
df[(df.batsman=='SR Tendulkar')][['total_runs']].sum()

# %%
df[(df.batsman=='SR Tendulkar')].loc[:,['total_runs']].sum()

# %%
df
# Out:
#        match_id  inning         batting_team                 bowling_team  \
# 0             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...         ...     ...                  ...                          ...
# 69756       295       2      Deccan Chargers                Pune Warriors
# 69757       295       2      Deccan Chargers                Pune Warriors
# 69758       295       2      Deccan Chargers                Pune Warriors
# 69759       295       2      Deccan Chargers                Pune Warriors
# 69760       295       2      Deccan Chargers                Pune Warriors
#
#        over  ball       batsman   non_striker        bowler  is_super_over  \
# ...

# %%
# Extra Runs Given By All Bowlers in a League.

df.groupby('bowler')[['extra_runs']].sum()
# Out:
#               extra_runs
# bowler
# A Choudhary            7
# A Flintoff             1
# A Kumble              62
# A Mishra              60
# A Mithun              19
# ...                  ...
# YA Abdulla            17
# YK Pathan             50
# YS Chahal             30
# Yuvraj Singh          11
# Z Khan                89
#
# [285 rows x 1 columns]

# %%
df.groupby('bowler')[['extra_runs']].value_counts()
# Out:
# bowler       extra_runs
# A Choudhary  0              101
#              1                7
# A Flintoff   0               65
#              1                1
# A Kumble     0              942
#                            ...
# Z Khan       0             1132
#              1               65
#              4                3
#              5                2
#              2                1
# Length: 808, dtype: int64

# %%
df.sort_values(by='extra_runs').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 df.sort_values(by='extra_runs').sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11074, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11054 @doc(
#   11055     _num_doc,
#   11056     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11072     **kwargs,
#   11073 ):
# > 11074     return NDFrame.sum(
#   11075         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11076     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10794, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10785 def sum(
#   10786     self,
#   10787     axis: Axis | None = None,
#    (...)
#   10792     **kwargs,
#   10793 ):
# ...

# %%
# total extra runs 

df['extra_runs'].sum()
# Out:
# 5121

# %%
df.extra_runs.sum()
# Out:
# 5121

# %%
df.loc[:,['extra_runs']].sum()
# Out:
# extra_runs    5121
# dtype: int64

# %%
df.loc[:,['bowler','extra_runs']]
# Out:
#              bowler  extra_runs
# 0          TS Mills           0
# 1          TS Mills           0
# 2          TS Mills           0
# 3          TS Mills           0
# 4          TS Mills           2
# ...             ...         ...
# 69756      R Sharma           0
# 69757      R Sharma           0
# 69758      R Sharma           1
# 69759      R Sharma           0
# 69760  Yuvraj Singh           0
#
# [69761 rows x 2 columns]

# %%
df.loc[:,['bowler','extra_runs']].sum()
# Out:
# bowler        TS MillsTS MillsTS MillsTS MillsTS MillsTS Mil...
# extra_runs                                                 5121
# dtype: object

# %%
# Extra Runs Given By TS Mills.

df[(df['bowler']=='TS Mills')][['extra_runs']].sum()
# Out:
# extra_runs    13
# dtype: int64

# %%
df[(df['bowler']=='TS Mills')].loc[:,['extra_runs']].sum()

# %%
df.groupby('bowler').get_group()

# %%
df.dismissal_kind.value_counts()
# Out:
# caught               2029
# bowled                650
# run out               379
# lbw                   223
# stumped               121
# caught and bowled     106
# retired hurt            4
# hit wicket              4
# Name: dismissal_kind, dtype: int64

# %%
# Catches Taken By Mandeep Singh.

df[(df.fielder=='Mandeep Singh') & (df.dismissal_kind=='caught')]

# %%
len(df[(df.fielder=='Mandeep Singh') & (df.dismissal_kind=='caught')])

# %%
df[(df.fielder=='Mandeep Singh') & (df.dismissal_kind=='caught')].shape[0]

# %%
# How Many Times DA Warner is dismissed by Mohammed Shami.

df[(df.player_dismissed=='DA Warner') & (df.bowler=="Mohammed Shami")]
# Out:
#       match_id  inning         batting_team      bowling_team  over  ball  \
# 9029        39       1  Sunrisers Hyderabad  Delhi Daredevils     6     2
#
#         batsman non_striker          bowler  is_super_over  ...  bye_runs  \
# 9029  DA Warner    S Dhawan  Mohammed Shami              0  ...         0
#
#       legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 9029            0            0             0             0           0
#
#       total_runs  player_dismissed dismissal_kind fielder
# 9029           0         DA Warner         bowled     NaN
#
# [1 rows x 21 columns]

# %%
df[(df.player_dismissed=='DA Warner') & (df.bowler=="Mohammed Shami")].shape[0]

# %%
# Total Number of Wickets Taken by YS Chahal.
df.groupby('bowler').get_group('YS Chahal')[['dismissal_kind']].value_counts().sum()
# Out:
# 14

# %%
df.groupby('bowler').get_group('YS Chahal')[['dismissal_kind']].value_counts()
# Out:
# dismissal_kind
# caught            11
# bowled             2
# stumped            1
# dtype: int64

# %%
df.groupby('bowler').get_group('YS Chahal').loc[:,['dismissal_kind']].value_counts()
# Out:
# dismissal_kind
# caught            11
# bowled             2
# stumped            1
# dtype: int64

# %%
df.groupby('bowler').get_group('YS Chahal').loc[:,['dismissal_kind']].value_counts().sum()
# Out:
# 14

# %%
df[(df.bowler=='YS Chahal')].loc[:,['dismissal_kind']].value_counts()
# Out:
# dismissal_kind
# caught            11
# bowled             2
# stumped            1
# dtype: int64

# %%
df[(df.bowler=='YS Chahal')].loc[:,['dismissal_kind']].value_counts().sum()
# Out:
# 14

# %%
# Find Number of Stump Out done by MS Dhoni.
df[(df.fielder=='MS Dhoni') & (df.dismissal_kind=='stumped')]
# Out:
#        match_id  inning                 batting_team            bowling_team  \
# 3024         13       2                Gujarat Lions  Rising Pune Supergiant
# 4006         17       2  Royal Challengers Bangalore  Rising Pune Supergiant
# 11944        51       1             Delhi Daredevils  Rising Pune Supergiant
# 28296       122       2  Royal Challengers Bangalore     Chennai Super Kings
# 32944       141       2             Delhi Daredevils     Chennai Super Kings
# 35415       152       1             Rajasthan Royals     Chennai Super Kings
# 35445       152       1             Rajasthan Royals     Chennai Super Kings
# 49905       211       2               Mumbai Indians     Chennai Super Kings
# 51089       216       2              Deccan Chargers     Chennai Super Kings
# 52411       222       1        Kolkata Knight Riders     Chennai Super Kings
# 52422       222       1        Kolkata Knight Riders     Chennai Super Kings
# ...

# %%
df[(df.fielder=='MS Dhoni') & (df.dismissal_kind=='stumped')].shape[0]
# Out:
# 17

# %%
len(df[(df.fielder=='MS Dhoni') & (df.dismissal_kind=='stumped')])
# Out:
# 17

# %%
# How Many Times S Dhawan Got Out by lbw.

df[(df.batsman=='S Dhawan') & (df.dismissal_kind=='lbw')]
# Out:
#        match_id  inning    batting_team     bowling_team  over  ball  \
# 31390       135       2  Mumbai Indians  Kings XI Punjab     5     1
# 46812       199       1  Mumbai Indians  Deccan Chargers     4     3
#
#         batsman   non_striker          bowler  is_super_over  ...  bye_runs  \
# 31390  S Dhawan     JP Duminy      YA Abdulla              0  ...         0
# 46812  S Dhawan  SR Tendulkar  Jaskaran Singh              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 31390            0            0             0             0           0
# 46812            0            0             0             0           0
#
#        total_runs  player_dismissed dismissal_kind fielder
# 31390           0          S Dhawan            lbw     NaN
# 46812           0          S Dhawan            lbw     NaN
#
# [2 rows x 21 columns]

# %%
len(df[(df.batsman=='S Dhawan') & (df.dismissal_kind=='lbw')])
# Out:
# 2

# %%
df[(df.batsman=='S Dhawan') & (df.dismissal_kind=='lbw')].shape[0]
# Out:
# 2

# %%
df[(df.player_dismissed=='S Dhawan') & (df.dismissal_kind=='lbw')]
# Out:
#        match_id  inning    batting_team     bowling_team  over  ball  \
# 31390       135       2  Mumbai Indians  Kings XI Punjab     5     1
# 46812       199       1  Mumbai Indians  Deccan Chargers     4     3
#
#         batsman   non_striker          bowler  is_super_over  ...  bye_runs  \
# 31390  S Dhawan     JP Duminy      YA Abdulla              0  ...         0
# 46812  S Dhawan  SR Tendulkar  Jaskaran Singh              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 31390            0            0             0             0           0
# 46812            0            0             0             0           0
#
#        total_runs  player_dismissed dismissal_kind fielder
# 31390           0          S Dhawan            lbw     NaN
# 46812           0          S Dhawan            lbw     NaN
#
# [2 rows x 21 columns]

# %%
# Total number sixes hit by MS Dhoni.


df[(df.batsman=='MS Dhoni') & (df.batsman_runs==6)]
# Out:
#        match_id  inning            batting_team                 bowling_team  \
# 2081          9       2  Rising Pune Supergiant             Delhi Daredevils
# 3905         17       1  Rising Pune Supergiant  Royal Challengers Bangalore
# 5975         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5993         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5999         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# ...         ...     ...                     ...                          ...
# 67428       285       1     Chennai Super Kings             Rajasthan Royals
# 68290       289       1     Chennai Super Kings             Delhi Daredevils
# 68335       289       1     Chennai Super Kings             Delhi Daredevils
# 68344       289       1     Chennai Super Kings             Delhi Daredevils
# 68345       289       1     Chennai Super Kings             Delhi Daredevils
#
# ...

# %%
len(df[(df['batsman']=='MS Dhoni') & (df['batsman_runs']==6)])
# Out:
# 62

# %%
df[(df.batsman=='MS Dhoni')][df.batsman_runs==6]
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_9616\307809944.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df.batsman=='MS Dhoni')][df.batsman_runs==6]
#        match_id  inning            batting_team                 bowling_team  \
# 2081          9       2  Rising Pune Supergiant             Delhi Daredevils
# 3905         17       1  Rising Pune Supergiant  Royal Challengers Bangalore
# 5975         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5993         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5999         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# ...         ...     ...                     ...                          ...
# 67428       285       1     Chennai Super Kings             Rajasthan Royals
# 68290       289       1     Chennai Super Kings             Delhi Daredevils
# 68335       289       1     Chennai Super Kings             Delhi Daredevils
# ...

# %%
len(df[(df.batsman=='MS Dhoni')][df.batsman_runs==6])
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_2464\3112752551.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(df[(df.batsman=='MS Dhoni')][df.batsman_runs==6])
# 62

# %%
df[(df.batsman=='MS Dhoni')][df.batsman_runs==6].shape[0]
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_2464\2063639384.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df.batsman=='MS Dhoni')][df.batsman_runs==6].shape[0]
# 62

# %%
df.groupby('batsman').get_group('MS Dhoni')[df.batsman_runs==6]
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_2464\2739052643.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.groupby('batsman').get_group('MS Dhoni')[df.batsman_runs==6]
#        match_id  inning            batting_team                 bowling_team  \
# 2081          9       2  Rising Pune Supergiant             Delhi Daredevils
# 3905         17       1  Rising Pune Supergiant  Royal Challengers Bangalore
# 5975         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5993         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# 5999         25       2  Rising Pune Supergiant          Sunrisers Hyderabad
# ...         ...     ...                     ...                          ...
# 67428       285       1     Chennai Super Kings             Rajasthan Royals
# 68290       289       1     Chennai Super Kings             Delhi Daredevils
# ...

# %%
df.groupby('batsman').get_group('MS Dhoni')[df.batsman_runs==6].shape[0]
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_2464\1624266011.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.groupby('batsman').get_group('MS Dhoni')[df.batsman_runs==6].shape[0]
# 62

# %%
# Total numbers of balls faced by MI Players.

df.groupby('batting_team').get_group('Mumbai Indians')[['batting_team','over']].value_counts()
# Out:
# batting_team    over
# Mumbai Indians  1       475
#                 2       466
#                 3       463
#                 4       463
#                 5       456
#                 8       449
#                 6       444
#                 13      443
#                 7       441
#                 9       440
#                 11      439
#                 12      437
#                 10      436
#                 14      428
#                 16      423
#                 15      419
#                 17      403
#                 18      390
#                 19      390
#                 20      357
# dtype: int64

# %%
df.groupby('batting_team').get_group('Mumbai Indians')[['batting_team','over']]
# Out:
#          batting_team  over
# 248    Mumbai Indians     1
# 249    Mumbai Indians     1
# 250    Mumbai Indians     1
# 251    Mumbai Indians     1
# 252    Mumbai Indians     1
# ...               ...   ...
# 69120  Mumbai Indians    20
# 69121  Mumbai Indians    20
# 69122  Mumbai Indians    20
# 69123  Mumbai Indians    20
# 69124  Mumbai Indians    20
#
# [8662 rows x 2 columns]

# %%
df.groupby('batting_team').get_group('Mumbai Indians')[['batting_team','over']].value_counts().sum()
# Out:
# 8662

# %%
df.groupby('batting_team').get_group('Mumbai Indians').loc[:,['batting_team','over']]
# Out:
#          batting_team  over
# 248    Mumbai Indians     1
# 249    Mumbai Indians     1
# 250    Mumbai Indians     1
# 251    Mumbai Indians     1
# 252    Mumbai Indians     1
# ...               ...   ...
# 69120  Mumbai Indians    20
# 69121  Mumbai Indians    20
# 69122  Mumbai Indians    20
# 69123  Mumbai Indians    20
# 69124  Mumbai Indians    20
#
# [8662 rows x 2 columns]

# %%
df.groupby('batting_team').get_group('Mumbai Indians').loc[:,['batting_team','over']].value_counts()
# Out:
# batting_team    over
# Mumbai Indians  1       475
#                 2       466
#                 3       463
#                 4       463
#                 5       456
#                 8       449
#                 6       444
#                 13      443
#                 7       441
#                 9       440
#                 11      439
#                 12      437
#                 10      436
#                 14      428
#                 16      423
#                 15      419
#                 17      403
#                 18      390
#                 19      390
#                 20      357
# dtype: int64

# %%
df.groupby('batting_team').get_group('Mumbai Indians').loc[:,['batting_team','over']].value_counts().sum()
# Out:
# 8662

# %%
# Total numbers of balls faced by KKR Players.
df.groupby('batting_team').get_group('Kolkata Knight Riders').loc[:,['batting_team','over']].value_counts().sum()
# Out:
# 7887

# %%
df.groupby('batting_team').get_group('Kolkata Knight Riders').loc[:,['batting_team','over']]
# Out:
#                 batting_team  over
# 617    Kolkata Knight Riders     1
# 618    Kolkata Knight Riders     1
# 619    Kolkata Knight Riders     1
# 620    Kolkata Knight Riders     1
# 621    Kolkata Knight Riders     1
# ...                      ...   ...
# 68792  Kolkata Knight Riders    13
# 68793  Kolkata Knight Riders    13
# 68794  Kolkata Knight Riders    13
# 68795  Kolkata Knight Riders    13
# 68796  Kolkata Knight Riders    13
#
# [7887 rows x 2 columns]

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Find the total number of runs scored by Sachin Tendulkar.

df.groupby('batsman').get_group('SR Tendulkar')[['total_runs']].sum()
# Out:
# total_runs    1730
# dtype: int64

# %%
df.groupby('batsman').get_group('SR Tendulkar').loc[:,['total_runs']].sum()
# Out:
# total_runs    1730
# dtype: int64

# %%
df[(df.batsman=='SR Tendulkar')][['total_runs']]
# Out:
#        total_runs
# 21015           1
# 21017           0
# 21025           0
# 21026           0
# 21027           0
# ...           ...
# 69087           1
# 69093           4
# 69094           1
# 69096           1
# 69098           0
#
# [1388 rows x 1 columns]

# %%
df[(df.batsman=='SR Tendulkar')][['total_runs']].sum()
# Out:
# total_runs    1730
# dtype: int64

# %%
df[(df.batsman=='SR Tendulkar')].loc[:,['total_runs']].sum()
# Out:
# total_runs    1730
# dtype: int64

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Find the total number of balls faced by Schin Tendulkar.

df[(df.batsman=='SR Tendulkar')][['batsman','ball']]
# Out:
#             batsman  ball
# 21015  SR Tendulkar     4
# 21017  SR Tendulkar     6
# 21025  SR Tendulkar     1
# 21026  SR Tendulkar     2
# 21027  SR Tendulkar     3
# ...             ...   ...
# 69087  SR Tendulkar     1
# 69093  SR Tendulkar     1
# 69094  SR Tendulkar     2
# 69096  SR Tendulkar     4
# 69098  SR Tendulkar     6
#
# [1388 rows x 2 columns]

# %%
len(df[(df.batsman=='SR Tendulkar')][['batsman','ball']])
# Out:
# 1388

# %%
df.groupby('batsman').get_group('SR Tendulkar').loc[:,['batsman','ball']]
# Out:
#             batsman  ball
# 21015  SR Tendulkar     4
# 21017  SR Tendulkar     6
# 21025  SR Tendulkar     1
# 21026  SR Tendulkar     2
# 21027  SR Tendulkar     3
# ...             ...   ...
# 69087  SR Tendulkar     1
# 69093  SR Tendulkar     1
# 69094  SR Tendulkar     2
# 69096  SR Tendulkar     4
# 69098  SR Tendulkar     6
#
# [1388 rows x 2 columns]

# %%
# Find Sachin Tendulkar's dismissal types in IPL.

df[(df.batsman=='SR Tendulkar')].loc[:,["dismissal_kind"]].value_counts()
# Out:
# dismissal_kind
# caught               23
# bowled                7
# lbw                   5
# run out               3
# caught and bowled     1
# stumped               1
# dtype: int64

# %%
df[(df.batsman=='SR Tendulkar')][["dismissal_kind"]].value_counts()
# Out:
# dismissal_kind
# caught               23
# bowled                7
# lbw                   5
# run out               3
# caught and bowled     1
# stumped               1
# dtype: int64

# %%
df.groupby('batsman').get_group('SR Tendulkar')[['dismissal_kind']].value_counts()
# Out:
# dismissal_kind
# caught               23
# bowled                7
# lbw                   5
# run out               3
# caught and bowled     1
# stumped               1
# dtype: int64

# %%
# Find the bowlers who dismissed SR Tendulkar.

df[(df.player_dismissed=='SR Tendulkar')][['bowler','dismissal_kind','player_dismissed']]
# Out:
#                 bowler     dismissal_kind player_dismissed
# 22501  Joginder Sharma             bowled     SR Tendulkar
# 23139    Shoaib Akhtar             caught     SR Tendulkar
# 23597    Shahid Afridi             caught     SR Tendulkar
# 24663        IK Pathan            run out     SR Tendulkar
# 25219        VY Mahesh             bowled     SR Tendulkar
# 26239       SK Trivedi  caught and bowled     SR Tendulkar
# 29727          PP Ojha             caught     SR Tendulkar
# 30608        LR Shukla                lbw     SR Tendulkar
# 31373         VS Malik             caught     SR Tendulkar
# 32028       AB Agarkar             caught     SR Tendulkar
# 33240       D du Preez             caught     SR Tendulkar
# 34298         RP Singh             bowled     SR Tendulkar
# 34887       PJ Sangwan            run out     SR Tendulkar
# 35588    R Vinay Kumar             caught     SR Tendulkar
# 37502         SK Warne                lbw     SR Tendulkar
# ...

# %%
df[(df.player_dismissed=='SR Tendulkar')][['bowler','dismissal_kind']].value_counts()
# Out:
# bowler           dismissal_kind
# A Mishra         caught               2
# SB Jakati        caught               1
# R Sharma         caught               1
#                  lbw                  1
# R Vinay Kumar    bowled               1
#                  caught               1
# RJ Harris        caught               1
# RP Singh         bowled               1
#                  caught               1
# SK Raina         caught               1
# AB Agarkar       caught               1
# SK Trivedi       caught and bowled    1
# SK Warne         lbw                  1
# Shahid Afridi    caught               1
# Shoaib Akhtar    caught               1
# T Thushara       caught               1
# VS Malik         caught               1
# VY Mahesh        bowled               1
# R Bhatia         bowled               1
# PP Ojha          caught               1
# PP Chawla        caught               1
#                  bowled               1
# AD Mascarenhas   lbw                  1
# ...

# %%
# How many times was Suresh Raina dismissed.
df[(df.player_dismissed=='SK Raina')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1261 to 68256
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          59 non-null     int64
#  1   inning            59 non-null     int64
#  2   batting_team      59 non-null     object
#  3   bowling_team      59 non-null     object
#  4   over              59 non-null     int64
#  5   ball              59 non-null     int64
#  6   batsman           59 non-null     object
#  7   non_striker       59 non-null     object
#  8   bowler            59 non-null     object
#  9   is_super_over     59 non-null     int64
#  10  wide_runs         59 non-null     int64
#  11  bye_runs          59 non-null     int64
#  12  legbye_runs       59 non-null     int64
#  13  noball_runs       59 non-null     int64
#  14  penalty_runs      59 non-null     int64
#  15  batsman_runs      59 non-null     int64
# ...

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Display player details who hit the maximum no of sixes in the current IPL tournament.


df.groupby('total_runs').get_group(6)[['batsman','total_runs']].value_counts()
# Out:
# batsman       total_runs
# SK Raina      6             82
# YK Pathan     6             80
# Yuvraj Singh  6             75
# RG Sharma     6             72
# CH Gayle      6             71
# dtype: int64

# %%
df.groupby('total_runs').get_group(6)[['batsman','total_runs']].value_counts().head()
# Out:
# batsman       total_runs
# SK Raina      6             82
# YK Pathan     6             80
# Yuvraj Singh  6             75
# RG Sharma     6             72
# CH Gayle      6             71
# dtype: int64

# %%
df.groupby('total_runs').get_group(6)[['batsman','total_runs']].value_counts().head(1)
# Out:
# batsman   total_runs
# SK Raina  6             82
# dtype: int64

# %%
df.groupby('total_runs').get_group(6)[['batsman','total_runs']].value_counts().head(1)[0]
# Out:
# 82

# %%
df[(df.total_runs==6)][['batsman','total_runs']].value_counts()
# Out:
# batsman       total_runs
# SK Raina      6             82
# YK Pathan     6             80
# Yuvraj Singh  6             75
# RG Sharma     6             72
# CH Gayle      6             71
#                             ..
# MA Khote      6              1
# M Rawat       6              1
# LPC Silva     6              1
# L Ronchi      6              1
# Z Khan        6              1
# Length: 233, dtype: int64

# %%
df[(df.total_runs==6)][['batsman','total_runs']].value_counts().head()
# Out:
# batsman       total_runs
# SK Raina      6             82
# YK Pathan     6             80
# Yuvraj Singh  6             75
# RG Sharma     6             72
# CH Gayle      6             71
# dtype: int64

# %%
df[(df.total_runs==6)][['batsman','total_runs']].value_counts().head(1)
# Out:
# batsman   total_runs
# SK Raina  6             82
# dtype: int64

# %%
df[(df.total_runs==6)][['batsman','total_runs']].value_counts().head(1)[0]
# Out:
# 82

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# What is the Overall No Balls Runs for each team in the dataset?

df.groupby('batting_team')[['batting_team','noball_runs']].sum()
# Out:
#                              noball_runs
# batting_team
# Chennai Super Kings                   32
# Deccan Chargers                       45
# Delhi Daredevils                      42
# Gujarat Lions                         10
# Kings XI Punjab                       36
# Kochi Tuskers Kerala                  11
# Kolkata Knight Riders                 39
# Mumbai Indians                        42
# Pune Warriors                          9
# Rajasthan Royals                      45
# Rising Pune Supergiant                 1
# Royal Challengers Bangalore           34
# Sunrisers Hyderabad                    6

# %%
# Which player scored the most runs in the dataset?
df.groupby('batsman')[['batsman','total_runs']].sum()
# Out:
#                total_runs
# batsman
# A Chopra               58
# A Choudhary            25
# A Flintoff             72
# A Kumble               42
# A Mishra              239
# ...                   ...
# YV Takawale            96
# Yashpal Singh          49
# Younis Khan             3
# Yuvraj Singh         1545
# Z Khan                 72
#
# [383 rows x 1 columns]

# %%
df.groupby('batsman')[['batsman','total_runs']].sum().sort_values('total_runs',ascending = False).
# Out:
#               total_runs
# batsman
# SK Raina            2255
# G Gambhir           2034
# RG Sharma           1867
# SR Tendulkar        1730
# MS Dhoni            1650
# ...                  ...
# C Nanda                0
# S Kaul                 0
# Imran Tahir            0
# SN Thakur              0
# L Ablish               0
#
# [383 rows x 1 columns]

# %%
# Create Your Own Question Atleast 20 To 30 Questions.

# %% [markdown]
# *ALL THE BEST*
